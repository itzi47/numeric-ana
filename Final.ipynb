# %% [markdown]
# # Predicting Employee Attrition - Job Change of Data Scientists

# %% [markdown]
# **Data Source**
# The dataset for this project is from Kaggle , [Predict who will move to a new job]((https://www.kaggle.com/code/khotijahs1/predict-who-will-move-to-a-new-job/inpute))).This dataset contains information about the demographic details of the employees, their education, job experience, and job change aims. Such data is of great value to enterprises because, through the data analysis, companies are able to predict employee attrition and hence develop effective strategies toward retaining talent.
#
# **Significance:**
#
# **Financial Impact** -high attrition percantage are costly due to the face of high  expenses in the recruiting process, hiring and training new employees.by predictin attrition the company will be able to create new strategies for retention and lower the cost .
#
# **Operational Continuity**- With experience and knowledge, experienced people also leave. Attrition prediction helps plan to ensure that all critical roles are always filled.
#
# **Employee Morale** -High employee attrition rates are a demoralizing factor to current employees and directly result in low productivity. Being able to predict employee turnover can help in addressing the underlying problems of dissatisfaction and, hence, positively influence employee morale.
#
# **Importance of the Solution**
#
# **Retention Strategies**- early detection of employees who will probably leave will help to consider new strategies that will help avoid losing them, providing better work conditions, personal motivation, and a goog career development path.
#
#  **Workforce planning** By anticipating employee attrition, workforce planning would work to ensure the organization has a talent pipeline ready for critical roles to mitigate disruption.
#
# **Organizational Stability** minimizing attrition offers a more stable workforce.This is necessary for high productivity and ensures the achievement of goals set for the organization in the long term.
#
#
# Besides having value on a practical level, knowledge and solutions to the problem of employee attrition would have benefits at a higher level. These assist in maintaining stable work, to underpin economic stability and growth, minimazing stress and anxiety on workers, and give a chance for a healthier and more inclusive working environment. The development of firm models that predict attrition would help to set up more nutritious and stable workplaces, which could benefit not only individual firms but also society in general.

# %% [markdown]
# # EDA

# %% [markdown]
# # Dataset Creation and Exploratory Data Analysis
#
# ## Dataset Creation
#
#
# In this stage, I will detail each variable in the dataset, its type, range of values, and its meaning in the context of the learning task. For continuous variables, I will present distributions, and for categorical variables, the prior probabilities. Additionally, I will draw conclusions from interesting combinations of explanatory variables using graphs and statistical measures.
#
# | Variable             | Type          | Value Range                        | Meaning                                                                 |
# |----------------------|---------------|------------------------------------|-------------------------------------------------------------------------|
# | **Target**           | Binary        | 0 - Not looking for a job change <br>1 - Looking for a job change      | my target variable – the machine learning model I build will classify whether a new data sample indicates an employee looking to change jobs or not. |
# | **enrollee_id**      | Categorical   | 2-33379                            | Unique identifier for each employee                                      |
# | **city**             | Categorical   | city_1 - city_180                  | Unique identifier for the city where the employee resides               |
# | **city_development_index** | Continuous | [0, 1]                            | Index indicating the development level of the city                      |
# | **gender**           | Categorical   | Male/Female/Other                  | Employee's gender                                                      |
# | **relevent_experience** | Binary    | Has/No relevent experience          | Whether the employee has relevant experience in the field               |
# | **enrolled_university** | Categorical | Full time course/no_enrollment/Part time course | Type of course the employee is enrolled in at the university            |
# | **education_level**  | Categorical   | Primary School/High School/Graduate/Masters/PhD | Employee's education level                                              |
# | **major_discipline** | Categorical   | Arts/Business Degree/Humanities/No Major/Other/STEM | Main field of study of the employee                                      |
# | **experience**       | Categorical   | <1/1-20/>20                        | Employee's years of experience                                         |
# | **company_size**     | Categorical   | <10/10-49/50-99/100-500/500-999/1000-4999/5000-9999/10000+ | Number of employees in the employee's company                         |
# | **company_type**     | Categorical   | Early Stage Startup/Funded Startup/NGO/Public Sector/Pvt Ltd/Other | Type of company the employee works for                                 |
# | **last_new_job**     | Categorical   | 1/2/3/4/>4/never                   | Number of years since the employee's last job                          |
# | **training_hours**   | Continuous    | [1, 336]                           | Number of training hours completed by the employee

# %% [markdown]
# ## Target - Looking for Job Change or Not
#
# The prior probabilities of the target variable are not balanced, as about three-quarters of the employees are not looking to change jobs, while about a quarter are. This may create a bias in the model learning, as the model recognizes approximately three times more samples with a specific label.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('aug_train.csv') 

plt.figure(figsize=(10, 6))
df['target'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Target - Looking for Job Change or Not')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Gender
#
# According to the data, about 90% of the respondents are men, and about 10% are women/others. Therefore, the values of this feature are not balanced.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', data=df, palette='viridis')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Relevant Experience
#
# According to research on the internet, DS training courses require a certain background from the candidates in order to complete the course, which aligns with the data.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='relevent_experience', data=df, palette='coolwarm')
plt.title('Relevant Experience Distribution')
plt.xlabel('Relevant Experience')
plt.ylabel('Count')
plt.show()

relevant_experience_counts = df['relevent_experience'].value_counts()
relevant_experience_proportions = df['relevent_experience'].value_counts(normalize=True) * 100
relevant_experience_summary = pd.DataFrame({
    'Amount': relevant_experience_counts,
    'P(Relevant experience)': relevant_experience_proportions
})
relevant_experience_summary
# Out:
#                          Amount  P(Relevant experience)
# relevent_experience
# Has relevent experience   13792               71.990813
# No relevent experience     5366               28.009187

# %% [markdown]
# ## Enrolled University
#
# According to the data, the majority of respondents (about 73%) are not enrolled in any university course. A small proportion of respondents (about 26%) are taking part-time or full-time courses.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='enrolled_university', data=df, palette='Set2')
plt.title('Enrolled University Distribution')
plt.xlabel('Enrolled University')
plt.ylabel('Count')
plt.show()

enrolled_university_counts = df['enrolled_university'].value_counts()
enrolled_university_proportions = df['enrolled_university'].value_counts(normalize=True) * 100
enrolled_university_summary = pd.DataFrame({
    'Amount': enrolled_university_counts,
    'P(Enrolled university)': enrolled_university_proportions
})
enrolled_university_summary
# Out:
#                      Amount  P(Enrolled university)
# enrolled_university
# no_enrollment         13817               73.604304
# Full time course       3757               20.013850
# Part time course       1198                6.381845

# %% [markdown]
# ## Education Level
#
# The vast majority of employees have a bachelor's or master's degree, which aligns with reality – after extensive internet research, I found that an employee needs to have a bachelor's degree, and often a master's degree, to be a DS.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='education_level', data=df, palette='cubehelix')
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

education_level_counts = df['education_level'].value_counts()
education_level_proportions = df['education_level'].value_counts(normalize=True) * 100
education_level_summary = pd.DataFrame({
    'Amount': education_level_counts,
    'P(Education level)': education_level_proportions
})
education_level_summary
# Out:
#                  Amount  P(Education level)
# education_level
# Graduate          11598           62.028024
# Masters            4361           23.323350
# High School        2017           10.787250
# Phd                 414            2.214141
# Primary School      308            1.647235

# %% [markdown]
# ## Company Size & Company Type
#
# Most existing companies today are "Pvt Ltd" companies, so this dataset represents reality, and usually, these companies do not have a small number of employees (which typically characterizes early-stage startups) or a very large number of employees.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='company_type', data=df, palette='Blues')
plt.title('Company Type Distribution')
plt.xlabel('Count')
plt.ylabel('Company Type')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(y='company_size', data=df, palette='Greens')
plt.title('Company Size Distribution')
plt.xlabel('Count')
plt.ylabel('Company Size')
plt.show()

# %% [markdown]
# ## City Development Index
#
# This variable is continuous with a mean of 0.83 and a median of 0.9 According to these data and the histogram, the data have a large left tail.

# %%
plt.figure(figsize=(7, 6))
plt.hist(df['city_development_index'], color='teal')
plt.title("Distribution of Candidates\nby city development indexes", fontsize=18, fontweight="bold")
plt.ylabel('Number of candidates', fontsize=12, fontweight="bold")
plt.xlabel('City development index', fontsize=12, fontweight="bold")
plt.show()

# %% [markdown]
# ## Last New Job
#
# According to the data, more than half of the employees are relatively "fresh" as it has been between one to two years since their previous job.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='last_new_job', data=df, palette='Greens')
plt.title('Last New Job Distribution')
plt.xlabel('Years Since Last Job')
plt.ylabel('Count')
plt.show()

last_new_job_counts = df['last_new_job'].value_counts()
last_new_job_proportions = df['last_new_job'].value_counts(normalize=True) * 100
last_new_job_summary = pd.DataFrame({
    'Amount': last_new_job_counts,
    'P(Last new job)': last_new_job_proportions
})
last_new_job_summary
# Out:
#               Amount  P(Last new job)
# last_new_job
# 1               8040        42.914331
# >4              3290        17.560715
# 2               2900        15.479050
# never           2452        13.087804
# 4               1029         5.492394
# 3               1024         5.465706

# %% [markdown]
# ## Training Hours
#
# This variable is continuous with a right-skewed distribution, a mean of 65.33, and a median of 47. The mean is higher than the median, indicating that most of the data points are from people who completed up to 50 training hours. It can be seen that the higher the number of training hours, the fewer people completed those many hours.

# %%
plt.figure(figsize=(7, 6))
plt.hist(df['training_hours'], color='darkslategrey')
plt.title("Training hours of the candidates", fontsize=18, fontweight="bold")
plt.ylabel('Number of candidates', fontsize=12, fontweight="bold")
plt.xlabel('Number of hours', fontsize=12, fontweight="bold")
plt.show()

# %% [markdown]
# ## Education Level & Gender
#
# According to the data, most of the samples are from men, and most of the observations for each education level are for men. For example, the majority of observations are for men with a Graduate degree. This situation does not represent reality - according to statistical analysis conducted by the UN, as of 2021, there are about 50% men and 50% women in the world. Therefore, I also looked at the percentages of men and women according to all education levels. This situation already more closely matches reality - after extensive internet research as of 2020, a higher percentage of women (but not by much) reach the education levels mentioned in the graph.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='education_level', hue='gender', data=df, palette='Set1')
plt.title('Education Level by Gender')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Education Level & City Development Index
#
# The graph shows a positive relationship between the employee's education level and the city's development index. From an index of about 0.65, I see more observations per education level as the index increases. Many studies support the idea that the socio-economic status of a person, reflected in part by the city they live in, influences the education level they attain during their lifetime.
# )

# %%
plt.figure(figsize=(8, 7))
plt.hist([df.loc[df['education_level'] == 'Primary School', 'city_development_index'], df.loc[df[
                                                                                                  'education_level'] == 'High School', 'city_development_index'],
          df.loc[df['education_level'] == 'Graduate', 'city_development_index'],
          df.loc[df['education_level'] == 'Masters', 'city_development_index'],
          df.loc[df['education_level'] == 'Phd', 'city_development_index']],
         color=['darkslategray', 'teal', 'steelblue', 'skyblue', 'lightsteelblue'], stacked=False)

from matplotlib.patches import Patch

Primary_School_patch = Patch(label='Primary School', color='darkslategray')
High_School_patch = Patch(label='High School', color='teal')
Graduate_patch = Patch(label='Graduate', color='steelblue')
Masters_patch = Patch(label='Masters', color='skyblue')
Phd_patch = Patch(label='Phd', color='lightsteelblue')

plt.legend(handles=[Primary_School_patch, High_School_patch, Graduate_patch, Masters_patch, Phd_patch])
plt.title("The level of education in cities \n with a different level of development", fontsize=18, fontweight="bold")
plt.ylabel('Number of candidates', fontsize=12, fontweight="bold")
plt.xlabel('City development index', fontsize=12, fontweight="bold")
plt.show()

# %% [markdown]
# ## Major Discipline & Education Level
#
# According to the data, the vast majority of employees in DS training programs come from disciplines related to science, technology, engineering, and mathematics (STEM). This aligns with reality, as data scientists need to have a background in one of these fields to qualify for jobs in this domain and generally to succeed in the training programs. Additionally, most of those coming from STEM disciplines hold a bachelor's or master's degree, which is the required education level for DS roles. I also found that there is more demand for those with a master's degree, but it is reasonable to assume that many bachelor's degree holders participate in training programs to bridge the gap and acquire relevant tools.

# %%
plt.figure(figsize=(10, 10))
p = sns.countplot(data=df, x='education_level', hue='major_discipline', palette='PuBuGn_r')
plt.title("Major discipline distribution\nof candidates with different education level", fontsize=20, fontweight="bold")
plt.ylabel('Number of candidates', fontsize=16, fontweight="bold")
plt.xlabel('Education level', fontsize=16, fontweight="bold")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
p.legend(title='Major discipline', bbox_to_anchor=(1, 1), fontsize=16)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

continuous_vars = ['city_development_index', 'training_hours', 'experience']

plt.figure(figsize=(10, 8))
sns.pairplot(df[continuous_vars])
plt.suptitle('Pairplot of Continuous Variables', y=1.02)  
plt.show()
# Out:
# C:\Users\mayoa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mayoa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mayoa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The city_development_index, training_hours, and the experience variable create distinct patterns. Most of the candidates are from highly developed cities, as illustrated by the clustering towards higher values of the city_development_index. Training hours are skewed towards the lower section, with the majority lying towards the lesser hours; experience has many variations, with the majority of them having over 20 years of experience. These variables showed a very poor correlation in their respective scatterplots, which would imply that each variable would be contributing differently and independently to the data with very little overlap, hence valuable for the model in understanding several aspects of candidate profiles.

# %% [markdown]
# ## Steps for Dataset Creation
#
# ### 1. Pre-processing
#
# In this part, I will perform several manipulations on the dataset to prepare it for use in the next stages:
#
# #### Redundancy in the Data
# I checked for duplicates in the data to see if there are any duplicate rows. I found that the data is without any duplicates, which might otherwise cause biases in the machine learning model later on.
#
# #### Missing Values
# - **Gender:** For this feature, I examined the distribution and filled missing values based on the probability of being male or female. If the generated number is smaller than the probability of being female, I filled it with "Female"; otherwise, I filled it with "Male".

# %%
import random

gender_val_cont = df["gender"].value_counts()
print(gender_val_cont)
gender_val_norm = df["gender"].value_counts(normalize=True)
print(gender_val_norm)

female_percent = gender_val_cont['Female'] / (gender_val_cont['Male'] + gender_val_cont['Female'])
male_percent = 1 - female_percent

for i in range(len(df)):
    if pd.isnull(df.loc[i, 'gender']):
        if random.random() <= female_percent:
            df.loc[i, 'gender'] = "Female"
        else:
            df.loc[i, 'gender'] = "Male"
# Out:
# gender
# Male      13221
# Female     1238
# Other       191
# Name: count, dtype: int64
# gender
# Male      0.902457
# Female    0.084505
# Other     0.013038
# Name: proportion, dtype: float64

# %%
missing_gender_count = df['gender'].isnull().sum()
missing_gender_percentage = (missing_gender_count / len(df)) * 100

print(f"Missing 'gender' records: {missing_gender_count} ({missing_gender_percentage:.2f}%)")
# Out:
# Missing 'gender' records: 4508 (23.53%)

# %% [markdown]
# 23.53% missing values of gender amount to 4,508 records, and removing them would highly reduce the data and affect its representativeness. Random imputation maintains the same distribution of male-female categories as it originally is, in order not to lose the integrity of the data by preserving the natural balance of the dataset without bias. In this way, it handles substantial missing data. It keeps the robustness of the dataset for analysis, and the feature importance will be reviewed again during the modeling phase to ensure it is still relevant.

# %% [markdown]
# - **Major Discipline:** For individuals with education levels "High School" or "Primary school", the `major_discipline` feature is not applicable. Hence, I filled missing values with "No Major", and for the remaining missing values, I used the mode which is "STEM".

# %%
for i in range(len(df)):
    if df.loc[i, 'education_level'] == 'High School' or df.loc[i, 'education_level'] == 'Primary School':
        df.loc[i, 'major_discipline'] = 'No Major'

df['major_discipline'].fillna("STEM", inplace=True)

# %% [markdown]
# - **Experience & Enrolled University:** I filled the missing values using the mode of each feature as they had relatively few missing values.

# %%
df['experience'].fillna(">20", inplace=True)
university_val_cont = df["enrolled_university"].value_counts()
df["enrolled_university"].fillna("no_enrollment", inplace=True)

# %% [markdown]
# - **Company Size & Company Type:** i filled missing values with "Unknown" due to a large number of missing values in these features to avoid creating a bias towards any particular value.

# %%
df['company_size'].fillna('Unknown', inplace=True)
df['company_type'].fillna('Unknown', inplace=True)

# %% [markdown]
#  - **Education Level & Last New Job:** Similar to the `gender` feature, I filled the missing values based on the probability of occurrence for each value in the data.

# %%
education_val_cont = df['education_level'].value_counts(normalize=True)
graduate_p = education_val_cont['Graduate']
masters_p = education_val_cont['Masters'] + graduate_p

for i in range(len(df)):
    if pd.isnull(df.loc[i, 'education_level']):
        r = random.random()
        if r <= graduate_p:
            df.loc[i, 'education_level'] = 'Graduate'
        elif graduate_p < r <= masters_p:
            df.loc[i, 'education_level'] = 'Masters'
        else:
            df.loc[i, 'education_level'] = 'High School'

last_new_job_cont = df['last_new_job'].value_counts()
last_new_job_norm = df['last_new_job'].value_counts(normalize=True)

one_p = last_new_job_norm["1"]
gfour_p = last_new_job_norm[">4"]
two_p = last_new_job_norm["2"]
never_p = last_new_job_norm["never"]
four_p = last_new_job_norm["4"]
three_p = last_new_job_norm["3"]

for i in range(len(df)):
    if pd.isnull(df.loc[i, 'last_new_job']):
        r = random.random()
        if r <= one_p:
            df.loc[i, 'last_new_job'] = "1"
        elif one_p < r <= one_p + gfour_p:
            df.loc[i, 'last_new_job'] = ">4"
        elif one_p + gfour_p < r <= one_p + gfour_p + two_p:
            df.loc[i, 'last_new_job'] = "2"
        elif one_p + gfour_p + two_p < r <= one_p + gfour_p + two_p + never_p:
            df.loc[i, 'last_new_job'] = "never"
        elif one_p + gfour_p + two_p + never_p < r <= one_p + gfour_p + two_p + never_p + four_p:
            df.loc[i, 'last_new_job'] = "4"
        else:
            df.loc[i, 'last_new_job'] = "3"

df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624   Male
# 3        33241  city_115                   0.789   Male
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience       no_enrollment        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20      Unknown         Unknown            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# This random imputation method maintains the original distribution of education_level and last_new_job by filling in missing values based on the probability of each category observed. This helps maintain natural variability in the data and natural relationships among variables in a manner that does not introduce bias. This imputation is necessary, as records are not missing trivially, and one would lose a great deal of information by simply removing the records. Feature selection will also validate those imputed features to retain only the informative ones. This does not corrupt the data but maintains the integrity of the data while maximizing usage of the available information.

# %% [markdown]
# ## Feature Extraction
#
# I want to extract the most informative features from my dataset to improve the performance of my machine learning model. I aim to create additional features based on my knowledge and research.
#
# ### Specific - Knowledge Based
#
# I used a specific-knowledge-based approach to create new features based on the research and domain knowledge about DS training programs. Here are the new features I created:
#
# - **Central_city:** A binary feature that indicates if the employee comes from a city with more than 1000 employees. This feature is created based on the idea that employees from more populated cities might have different job-changing behaviors due to more job opportunities.
# - **Experience_index:** A binary feature that indicates if the employee has 7 or more years of experience. I believe that having 7 or more years of experience might influence an employee's decision to stay or leave the job after completing a DS training program.

# %%
city_cont = df['city'].value_counts()
Central_city = []
for i in range(len(df)):
    if city_cont[df.loc[i, 'city']] > 1000:
        Central_city.append(1)
    else:
        Central_city.append(0)
df['Central_city'] = Central_city

# %%
Experience_index = []
for i in range(len(df)):
    if df.loc[i, 'experience'] == '>20':
        Experience_index.append('1')
    elif df.loc[i, 'experience'] == '<1':
        Experience_index.append('0')
    elif int(df.loc[i, 'experience']) >= 7:
        Experience_index.append('1')
    else:
        Experience_index.append('0')

df['Experience_index'] = Experience_index

# %% [markdown]
# ## Feature Representation
#
# ### Training Hours
#
# I normalized the `training_hours` feature by dividing each value by the maximum value in the column.
#
# ### Experience
#
# I converted the `experience` feature from string categories to numerical values. This allows me to better capture the ordinal nature of the feature.

# %%
df['training_hours'] = df['training_hours'] / df['training_hours'].max()

df['experience'].replace({'<1': '0', '>20': '21'}, inplace=True)
df['experience'] = df['experience'].astype(int)

df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624   Male
# 3        33241  city_115                   0.789   Male
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience       no_enrollment        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type last_new_job  \
# 0             STEM          21      Unknown         Unknown            1
# 1             STEM          15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# ## Feature Selection
# **Quantitative Approach:**
#
# Quantitatively, the feature selection should is guided by conducting a logistic regression test on the dataset as to how each feature correlates with the probability of the target event. The logistic regression results illustrated that features such as city_development_index, training_hours, and experience had significant coefficients, with p-values below 0.05. This shows that these features are highly related to the target variable statistically, hence their presence in the model is important to its predictive power. From these coefficients, the city_development_index and experience are negatively related to the likelihood of occurrence of the target event, while the training hours also detract from the target. Though the Pseudo R-squared value is small, these featured variables contribute jointly in a significant way to the explanation of the target variable. This quantitative evidence gave a good basis for prioritizing these statistically significant features in the model.

# %%
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

X = df[['training_hours', 'city_development_index', 'experience']]
y = df['target']

X = sm.add_constant(X)

model = sm.Logit(y, X).fit()

print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.503983
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                 target   No. Observations:                19158
# Model:                          Logit   Df Residuals:                    19154
# Method:                           MLE   Df Model:                            3
# Date:                Fri, 30 Aug 2024   Pseudo R-squ.:                  0.1026
# Time:                        22:15:36   Log-Likelihood:                -9655.3
# converged:                       True   LL-Null:                       -10759.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Qualitative Approach:**
#
# Complementarily, to the quantitative feature analysis, a qualitative approach was employed through graphical analysis of relationships between features and the target variable. The graphical display comprised bar plots and count plots for the categorical variables: `Enrolled University`, `Education Level`, `Major Discipline`, `Company Size`, and `Company Type` against the target. These plots had distinct patterns and distributions, such as how higher levels of education correspond to lower rates of job changing, and how company type or size relates to seeking new employment. These differences, based on the statistical tests including the F-statistic and p-values, showed the variations observed were not due to random chance. Such a qualitative examination naturally brought an increased insight into how different groups behave in relation to the target by reinforcing decisions made at feature selection, making sure the retained features are not only statistically significant but practically meaningful concerning the business problem tackled.
#
# This feature selection is intense, data-driven, and aligned with patterns observed in the dataset because it draws on both quantitative and qualitative approaches. Using this model ensures that a dual approach is included for features to be part of the model, ensuring that features are added for their meaningful contribution, rather than the shortcomings brought about by subjective decision-making using clear and objective evidence from the data.

# %%
from scipy import stats
def plot_categorical_vs_target_side_by_side(column):
    
    data = df.dropna(subset=[column, 'target'])
    counts = data.groupby([column, 'target']).size().unstack(fill_value=0)

    
    ax = counts.plot(kind='bar', figsize=(10, 6))
    ax.set_title(f'{column.replace("_", " ").capitalize()} vs Target')
    ax.set_xlabel(column.replace("_", " ").capitalize())
    ax.set_ylabel('Count')
    plt.show()

plot_categorical_vs_target_side_by_side('enrolled_university')
F, p_value = stats.f_oneway(df[df.enrolled_university == 'no_enrollment'].target,
                            df[df.enrolled_university == 'Part time course'].target,
                            df[df.enrolled_university == 'Full time course'].target)
print("Enrolled university-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)

plot_categorical_vs_target_side_by_side('education_level')
F, p_value = stats.f_oneway(df[df.education_level == 'High School'].target,
                            df[df.education_level == 'Masters'].target, df[df.education_level == 'Graduate'].target,
                            df[df.education_level == 'Phd'].target, df[df.education_level == 'Primary School'].target)
print("Education level-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)
# Major Discipline vs Target
plot_categorical_vs_target_side_by_side('major_discipline')
F, p_value = stats.f_oneway(df[df.major_discipline == 'No Major'].target,
                            df[df.major_discipline == 'STEM'].target, df[df.major_discipline == 'Humanities'].target,
                            df[df.major_discipline == 'Arts'].target, df[df.major_discipline == 'Other'].target,
                            df[df.major_discipline == 'Business Degree'].target)
print("Major discipline-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)

plot_categorical_vs_target_side_by_side('company_size')

plot_categorical_vs_target_side_by_side('company_type')
F, p_value = stats.f_oneway(df[df.company_type == 'Pvt Ltd'].target,
                            df[df.company_type == 'NGO'].target, df[df.company_type == 'Public Sector'].target,
                            df[df.company_type == 'Unknown'].target, df[df.company_type == 'Funded Startup'].target,
                            df[df.company_type == 'Early Stage Startup'].target, df[df.company_type == 'Other'].target)
print("Company type-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)

plot_categorical_vs_target_side_by_side('last_new_job')
F, p_value = stats.f_oneway(df[df.last_new_job == '1'].target,
                            df[df.last_new_job == '2'].target, df[df.last_new_job == '3'].target,
                            df[df.last_new_job == '4'].target, df[df.last_new_job == '>4'].target,
                            df[df.last_new_job == 'never'].target)
print("Last new job-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)

plt.figure(figsize=(10, 6))
data = df.dropna(subset=['city', 'target'])
counts = data.groupby(['city', 'target']).size().unstack(fill_value=0)
ax = counts.plot(kind='bar', figsize=(10, 6))
ax.set_title('City vs Target')
ax.set_xlabel('City')
ax.set_ylabel('Count')
plt.xticks(rotation=90)
plt.show()
print("City-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)

plot_categorical_vs_target_side_by_side('Experience_index')
print("Experience index-")
print("F statistic of the test: ", F, "p-value from the F distribution", p_value)
# Out:
# Enrolled university-
# F statistic of the test:  225.37640204794647 p-value from the F distribution 1.7954130887670052e-97
# Education level-
# F statistic of the test:  41.570447711182894 p-value from the F distribution 9.32187533335901e-35
# Major discipline-
# F statistic of the test:  12.648060667856813 p-value from the F distribution 2.721729195769522e-12
# Company type-
# F statistic of the test:  168.34754558265251 p-value from the F distribution 2.0616481134839245e-209
# Last new job-
# F statistic of the test:  26.411224461478326 p-value from the F distribution 1.0818804615773994e-26
# City-
# F statistic of the test:  26.411224461478326 p-value from the F distribution 1.0818804615773994e-26
# Experience index-
# F statistic of the test:  26.411224461478326 p-value from the F distribution 1.0818804615773994e-26

# %% [markdown]
# ### Analysis of Feature vs Target Graphs

# %% [markdown]
# enrolled_university vs. Target: I can observe the differences in the ratios, for instance, between full-time courses and "no enrollment." the likelihood of remaining in the position is far higher, indicating that this feature is important and that I'll want to preserve it.
#
# Target vs. Education level: It appears that the ratio differences are much smaller or much closer.companyfirm size vs. targetcan may observe differences in the ratio betwefor instancesay, "unknown" and other possibilities. the likelihoodchangingn in the position is far higher, indicating that this feature is important and that I'll want to preserve
#
# company type vs. target: I can observe differences in the ratio between, for instance "unknown" and PVT lts the likelihood of changing the position is far higher, indicating that this feature is important and that I'll want to preserve it.
#
# city - this is a feature with very high cardinality , not much insights from the graph
#
#
# Experience index vs. target: I can observe differences in the ratio between the different options indicating that this features are important and that I'll want to preserve them

# %% [raw]
# In feature selection, I chose the most informative features for my machine learning model based on various criteria as explained below:
#
# - **Enrollee_id:** I chose to remove this feature because it carries absolutely no useful information for the prediction task.
# - **Gender:** I chose to remove this feature to avoid any bias based on gender.
# - **Experience & City Development Index & Training Hours:** I chose to retain those features in order to study the relations between employee experience, training hours, and the development index of his city with the target variable.
# Relevant Experience, Enrolled University, Education Level, Major Discipline, Company Size, Company Type, Last New J also kept these features because they give important information to build my analysis for further steps in the next cells.
#
#
# City I removed a prefix, namely 'city_' from the feature city. It is not necessary in the analysis.

# %% [markdown]
# ### Encoding Categorical Variables
#
# I transformed the categorical variables into numerical values using label encoding and one-hot encoding to ensure that the machine learning model can process them correctly.

# %%
df['city'] = df['city'].str.replace('city_', '')

df['experience'].replace({'<1': '0', '>20': '21'}, inplace=True)
df['experience'] = df['experience'].astype(int)
df['experience'] = df['experience'] / max(df['experience'])

last_new_job_mapping = {'1': 1, '2': 2, '3': 3, '4': 4, '>4': 5, 'never': 0}
df['last_new_job'] = df['last_new_job'].map(last_new_job_mapping)

enrolled_university_mapping = {'Full time course': 2, 'Part time course': 1, 'no_enrollment': 0}
df['enrolled_university'] = df['enrolled_university'].map(enrolled_university_mapping)

education_level_mapping = {'Primary School': 1, 'High School': 2, 'Graduate': 3, 'Masters': 4, 'Phd': 5}
df['education_level'] = df['education_level'].map(education_level_mapping)

company_size_mapping = {'<10': 1, '10-49': 2, '50-99': 3, '100-500': 4, '500-999': 5, '1000-4999': 6, '5000-9999': 7, '10000+': 8, 'Unknown': 0}
df['company_size'] = df['company_size'].map(company_size_mapping)

df['training_hours'] = df['training_hours'] / max(df['training_hours'])

# %% [markdown]
# ## Dimensionality Reduction
#
#
# At this point, I'll want to downsize my feature set to reduce the number of features and get a more informative set. This move even saves time and reduces the complexity of the calculation when running the model. Additional goals of this phase are to visualize the data and create a combination of existing features. In order to reduce the dimension, I will use the PCA-Principle component analysis method , which maximizes the variability in the data so that I can determine which features are good for me. When testing the significance of the relationship between the continuous features and the target variable, I found that the relationship is significant, so I would not want to remove any of them from the model. However, I chose to do the process in order to experience it. I put the 3 continuous variables into the PCA algorithm to reduce dimension to 2. In the graph , you can see that  that PCA1 captures 70% of the variance, so I would like to leave it in the model. Also, PCA2 captures 21% of the variance and although it is not high I would like to keep it. PCA3, on the other hand, has the lowest variance percentage (9%) and was therefore chosen to be removed. (Note - I normalized the continuous variables by dividing by the maximum so that they are all between 0 and 1 and would not want to remove any of them from the model)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

x = df[['city_development_index', 'training_hours', 'experience']].values

pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principal_Df = pd.DataFrame(data=principalComponents, columns=['PC1', 'PC2', 'PC3'])

print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))

plt.figure(figsize=(10, 6))
plt.bar(['PC1', 'PC2', 'PC3'], pca.explained_variance_ratio_ * 100, color='skyblue')
plt.xlabel('Principal Components', fontsize=14)
plt.ylabel('Variance Explained (%)', fontsize=14)
plt.title('Explained Variation per Principal Component', fontsize=16)
plt.show()
# Out:
# Explained variation per principal component: [0.70185871 0.2103751  0.08776619]

# %% [markdown]
# # Clustering
#
# k-medoid is an algorithm for unsupervised learning, meaning without class labels, and its goal is to perform clustering rather than prediction or classification. Therefore I removed the target variable and adapted the dataset for the learning task. Additionally, the dataset is normalized, and categorical variables were converted to dummy variables I expect to get a model with two clusters, as the original model has two classes - 0 and 1
#  I will use a feature set containing all the features except CITY and Enrolee ID, similar to the dataset on which I ran the other learning algorithms I will use the Gower distance metric to measure distance since each record in the dataset contains a combination of categorical, continuous, and binary data. The Gower distance is a number between 0 (identical) and 1 (maximally different). The Gower distance is calculated as the average of the partial differences between individuals. The general form of the coefficient is as follow
# s
# I ran the algorithm and chose different Ks in the range of [2,8]
#
# I saved the results obtained for each K examined and checked the following properties:
# - Homogeneity (dense and close points to the cluster).
# - Separation (good separation between cluster cenis).
#
# I will check the existence of these properties using the following metrics:
# - SiIouette - I want to maximize this score, as a higher score indicates better separation and compactness within clusters.
# - DavieIBouldin - I want to minimize this score, as a lower score indicates better separation and compactness within clusters.
#
# Based on the Davies-Bouldin index, the optimal number of clusters is 2-3, and based on the Silhouette score, the optimal number of clusters is 2 Therefore, I decided that the optimal number of clusters is K=2 Given that I obtained the expected number of clusters (2), it can be assumed that each cluster represents 0 or 1 according to the labels assigned to each sample in the original dataset.

# %%
import gower
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import silhouette_score, davies_bouldin_score
import matplotlib.pyplot as plt


gower_dist = gower.gower_matrix(X_imputed)


k_values = range(2, 9)

silhouette_scores = []
davies_bouldin_scores = []

for k in k_values:
    kmedoids = KMedoids(n_clusters=k, metric='precomputed', random_state=42)
    kmedoids.fit(gower_dist)
    
    labels = kmedoids.labels_
    
    silhouette_avg = silhouette_score(gower_dist, labels, metric='precomputed')
    davies_bouldin_avg = davies_bouldin_score(gower_dist, labels)
    
    silhouette_scores.append(silhouette_avg)
    davies_bouldin_scores.append(davies_bouldin_avg)
    
    print(f'For k={k}, Silhouette Score: {silhouette_avg}, Davies-Bouldin Score: {davies_bouldin_avg}')


plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(k_values, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different k')


plt.subplot(1, 2, 2)
plt.plot(k_values, davies_bouldin_scores, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Davies-Bouldin Score')
plt.title('Davies-Bouldin Score for Different k')

plt.tight_layout()
plt.show()
# Out:
# For k=2, Silhouette Score: 0.17097145318984985, Davies-Bouldin Score: 2.2448381214170423
# For k=3, Silhouette Score: 0.06741885840892792, Davies-Bouldin Score: 3.698892893035944
# For k=4, Silhouette Score: 0.034979142248630524, Davies-Bouldin Score: 13.259030043581305
# For k=5, Silhouette Score: 0.0021616725716739893, Davies-Bouldin Score: 13.002025019866144
# For k=6, Silhouette Score: -0.006727529689669609, Davies-Bouldin Score: 15.60005022357263
# For k=7, Silhouette Score: 0.04691304638981819, Davies-Bouldin Score: 11.969560955779645
# For k=8, Silhouette Score: 0.05305982008576393, Davies-Bouldin Score: 9.631210287846766

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

continuous_vars = ['city_development_index', 'training_hours', 'experience']

X_continuous = X_imputed[continuous_vars]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_continuous)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=3, random_state=42)  # You can adjust the number of clusters (k) as needed
clusters = kmeans.fit_predict(X_pca)

pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
pca_df['Cluster'] = clusters

plt.figure(figsize=(10, 6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Cluster', palette='viridis', s=50, alpha=0.8)
plt.title('KMeans Clustering of Continuous Variables (PCA Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ###  Problem Definition
#
#  The problem is the likelihood that an employee will look for, or will not look for, a job change. It is a binary classification problem in which an objective is to categorize each employee into one of two classes: those who are not looking to change their current job (class 0) and those looking to change their current job (class 1). This can be considered an easy prediction since it is binary in nature, but it does require a robust model that can classify between the two based on the input features.

# %% [markdown]
# ## Model Training
#
# i will use the following methods for training my model and evaluating its performance:
# The validation method I will use is Cross Validation. There are three ways to implement this method: k-fold, leave one out and holdout. Among these three methods, I chose to use the k-fold method. In this method, K different divisions of the data are made into a training set and a validation set, so that each sample is both in the training set (k-1 times) and in the validation set (once). After the training phase, K models are created, which are weighted into one more balanced model that reduces the bias in the test phase. On the other hand, with the holdout method, the division into percentages may not be good so that it does not adequately capture the variability in the data. In addition to this, the leave one out method leaves one sample each time for validation and allocates the rest for training, which means that a huge amount of iterations will be performed (as the number of samples in my data) compared to only K iterations in the k-fold method. In light of all this, I chose to use the k-fold method over the others.
# To implement the method I will choose k=10 , and divide my data set so that each time one part of the data set will be used for validation, while the other nine parts will be used for training. In addition, I calculate the value that will be obtained in each validation according to the MSE metric - the average of the squared errors. That is, I calculate the average of the squared differences between the actual value and the value that the model estimates, and thus I can estimate the correctness of the model. Finally, I will have K MSE values, which I will average to get the metric value.

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np


X = df[['city_development_index', 'training_hours', 'experience']]
y = df['target']

model = LinearRegression()

kf = KFold(n_splits=10, shuffle=True, random_state=42)
mse_values = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

average_mse = np.mean(mse_values)

print(f'K-Fold Cross-Validation MSE values: {mse_values}')
print(f'Average K-Fold Cross-Validation MSE: {average_mse}')
# Out:
# K-Fold Cross-Validation MSE values: [0.161142454003148, 0.16855717231020934, 0.1742552509634994, 0.17208398272412778, 0.1664674816693282, 0.15670573285914466, 0.16268233738186497, 0.16055937439470047, 0.15990058858568465, 0.1626669182939955]
# Average K-Fold Cross-Validation MSE: 0.16450212931857028

# %% [markdown]
# The KMeans clustering with continuous variables, visualized through PCA, reveals three distinct clusters and highlights that cluster 0 is more spread out, indicating greater variability within this group. This dispersion suggests that cluster 0 includes a diverse range of employee profiles influenced by different combinations of experience, training hours, and city development index.

# %% [markdown]
# ## Decision Trees
#
# First, I built a model without selecting the most important features, and this is the result of the model's training:
# - **Train Accuracy:** 0.998760276654052
# - **Validation Accuracy:** 0.7267745302713987
#
#
# This indicates overfitting, as the model performs perfectly on the training data but poorly on the validation data. To address this, I will use Grid Search to find the best hyperparameters for my decision tree model.
#
# ### Grid Search Hyperparameters
#
# I tested various hyperparameters using Grid Search to find the optimal settings for my decision tree model. The parameters and their tested values are as follows:
#
# | Parameter        | Description                                                                                         | Values               |
# |------------------|-----------------------------------------------------------------------------------------------------|----------------------|
# | **Max_depth**    | The maximum depth of the tree. Setting this parameter helps prevent overfitting.                    | [None, 10, 20, 30]   |
# | **Max_features** | The number of features to consider when looking for the best split.                                 | [None, 'sqrt', 'log2']|
# | **Criterion**    | The function to measure the quality of a split.                                                     | ['gini', 'entropy']  |
# | **Min_samples_split** | The minimum number of samples required to split an internal node.                             | [2, 5, 10]           |
#
# ### Model Performance
#
# After applying Grid Search with 10-fold cross-validation, the model achieved the following results:
# - **Train Accuracy:** 0.8201748662403758
# - **Validation Accuracy:** 0.7852296450939458

# %%
dt_model_initial = DecisionTreeClassifier(random_state=42)
dt_model_initial.fit(X_train, y_train)

train_accuracy_initial = dt_model_initial.score(X_train, y_train)
validation_accuracy_initial = dt_model_initial.score(X_test, y_test)

print(f'Initial Train Accuracy: {train_accuracy_initial}')
print(f'Initial Validation Accuracy: {validation_accuracy_initial}')
# Out:
# Initial Train Accuracy: 0.998760276654052
# Initial Validation Accuracy: 0.7173799582463466

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score


df = pd.get_dummies(data=df, columns=['city', 'relevent_experience', 'gender', 'major_discipline', 'company_type'])

X = df.drop(columns=['enrollee_id', 'target'])
y = df['target']

imputer = SimpleImputer(strategy='mean')
X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

dt_model = DecisionTreeClassifier(random_state=42)

param_grid = {
    'max_depth': [None, 10, 20, 30],
    'max_features': [None, 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(estimator=dt_model, param_grid=param_grid, cv=10, scoring='accuracy', return_train_score=True)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print(f'Best Parameters: {best_params}')

best_dt_model = grid_search.best_estimator_
best_dt_model.fit(X_train, y_train)

train_accuracy = best_dt_model.score(X_train, y_train)
validation_accuracy = best_dt_model.score(X_test, y_test)
print(f'Train Accuracy: {train_accuracy}')
print(f'Validation Accuracy: {validation_accuracy}')

importances = best_dt_model.feature_importances_
features = X.columns
indices = np.argsort(importances)[::-1]

top_features = [features[i] for i in indices[:4]]
top_importances = importances[indices[:4]]
print("Top 4 features:")
for feature, importance in zip(top_features, top_importances):
    print(f"{feature}: {importance}")

X_top = X_imputed[top_features]

X_train_top, X_test_top, y_train, y_test = train_test_split(X_top, y, test_size=0.2, random_state=42)

best_dt_model_top = DecisionTreeClassifier(
    max_depth=best_params['max_depth'],
    random_state=42,
    max_features=best_params['max_features'],
    criterion=best_params['criterion'],
    min_samples_split=best_params['min_samples_split']
)
best_dt_model_top.fit(X_train_top, y_train)


train_accuracy_top = best_dt_model_top.score(X_train_top, y_train)
validation_accuracy_top = best_dt_model_top.score(X_test_top, y_test)
print(f'Train Accuracy with top features: {train_accuracy_top}')
print(f'Validation Accuracy with top features: {validation_accuracy_top}')
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_split': 5}
# Train Accuracy: 0.8186741485058071
# Validation Accuracy: 0.7888830897703549
# Top 4 features:
# city_development_index: 0.3907200311456066
# company_size: 0.23728360997056225
# training_hours: 0.08742145620063906
# education_level: 0.058107344865611484
# Train Accuracy with top features: 0.8059506720605507
# Validation Accuracy with top features: 0.7865344467640919

# %%
train_accuracies = []
val_accuracies = []
depths = [None,1, 10, 20, 30, 40]

for depth in depths:
    dt_model = DecisionTreeClassifier(max_depth=depth, random_state=42)
    dt_model.fit(X_train, y_train)
    train_accuracies.append(dt_model.score(X_train, y_train))
    val_accuracies.append(dt_model.score(X_test, y_test))

plt.figure(figsize=(12, 6))
plt.plot(depths, train_accuracies, label='Train Accuracy', marker='o')
plt.plot(depths, val_accuracies, label='Validation Accuracy', marker='o')
plt.xlabel('Tree Depth')
plt.ylabel('Accuracy')
plt.title('Tree Depth vs. Train and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Feature Importance
#
# Through feature selection and the importance of the different features, I can see which features are the most important for my decision-making process. This will help to understand the most significant features affecting my target variable.
#
# ### Calculating Feature Importance
#
# The following graph and values show the importance of each feature based on the model's training:

# %%
import matplotlib.pyplot as plt

top_features = [features[i] for i in indices[:4]]
top_importances = importances[indices[:4]]

plt.figure(figsize=(10, 6))
plt.barh(top_features, top_importances, color='skyblue')
plt.xlabel('Feature Importance')
plt.title('Top 4 Features by Importance')
plt.gca().invert_yaxis()  
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred_dt = best_dt_model_top.predict(X_test_top)

cm_dt = confusion_matrix(y_test, y_pred_dt)

disp_dt = ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=['Not Looking for Job Change', 'Looking for Job Change'])
disp_dt.plot(cmap='Blues')
plt.title('Confusion Matrix - Decision Tree with Top Features')
plt.show()

# %%
explainer_dt = shap.TreeExplainer(best_dt_model_top)
shap_values_dt = explainer_dt.shap_values(X_top)
shap.summary_plot(shap_values_dt, X_top, plot_type="bar")
shap.summary_plot(shap_values_dt, X_top)

# %% [markdown]
# The SHAP analysis from this Decision Tree model shows that the city_development_index and company_size features have a great impact on the model's predictions. The summary plots show such features contribute differently to their bands of values, where the SHAP values show clear positive and negative influences on the target variable. The difference in the SHAP values shows that the higher city development indices and sure company size are responsible for cases with different probabilities of job change. The feature impact summary visualization emphasized that the model features rely on differentiating between employees likely to change jobs from those not likely, hence justifying the importance of these features to the task of prediction.

# %%
from sklearn.tree import plot_tree
best_dt_model_depth_3 = DecisionTreeClassifier(
    max_depth=3,
    random_state=42,
    max_features=best_params['max_features'],
    criterion=best_params['criterion'],
    min_samples_split=best_params['min_samples_split']
)
best_dt_model_depth_3.fit(X_train, y_train)

plt.figure(figsize=(20, 10))
plot_tree(best_dt_model_depth_3, filled=True, feature_names=X.columns, class_names=['0', '1'], rounded=True)
plt.show()

# %% [markdown]
# ## Artificial Neural Networks
#
# Initially, I will standardize the data using `StandardScaler`. The following table lists the architecture of the neural network model I will use:
#
# | Parameter               | Value                     |
# |-------------------------|---------------------------|
# | Input Layer Neurons     | Number of input features  |
# | Hidden Layers           | 1                         |
# | Neurons in Hidden Layer | 100 (in MLPClassifier)    |
# | Output Layer Neurons    | 2 (number of classes)     |
#
# The plot obtained for the model configuration is as follows:

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

ann_model_initial = MLPClassifier(random_state=42)
ann_model_initial.fit(X_train, y_train)

train_accuracy_initial = ann_model_initial.score(X_train, y_train)
validation_accuracy_initial = ann_model_initial.score(X_test, y_test)

print(f'Initial Train Accuracy: {train_accuracy_initial}')
print(f'Initial Validation Accuracy: {validation_accuracy_initial}')
# Out:
# Initial Train Accuracy: 0.8670886075949367
# Initial Validation Accuracy: 0.7674843423799582
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'hidden_layer_sizes': [(50,), (100,)],
    'activation': ['relu'],
    'solver': ['adam'],
    'learning_rate': ['constant'],
    'max_iter': [200]
}

grid_search_ann = GridSearchCV(estimator=MLPClassifier(random_state=42), param_grid=param_grid, cv=5, scoring='accuracy', return_train_score=True)
grid_search_ann.fit(X_train, y_train)

best_params_ann = grid_search_ann.best_params_
print(f'Best Parameters: {best_params_ann}')

best_ann_model = grid_search_ann.best_estimator_
best_ann_model.fit(X_train, y_train)

train_accuracy_optimized = best_ann_model.score(X_train, y_train)
validation_accuracy_optimized = best_ann_model.score(X_test, y_test)

print(f'Optimized Train Accuracy: {train_accuracy_optimized}')
print(f'Optimized Validation Accuracy: {validation_accuracy_optimized}')
# Out:
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
y_pred_ann = best_ann_model.predict(X_test)

cm_ann = confusion_matrix(y_test, y_pred_ann)

disp_ann = ConfusionMatrixDisplay(confusion_matrix=cm_ann, display_labels=['Not Looking for Job Change', 'Looking for Job Change'])
disp_ann.plot(cmap='Blues')
plt.title('Confusion Matrix - Artificial Neural Network')
plt.show()

# %% [markdown]
# | Parameter            | Motivation                                                                                                                                                      | Model Impact                                                                                                                                                                                                                                                                      |
# |----------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Hidden layer size    | Number of layers and neurons in the hidden layer. I chose to check different hidden layer sizes to examine various network complexities and their impact on accuracy. | As the number of neurons in the hidden layer increases, the accuracy generally improves up to a certain point. Beyond this point, additional neurons do not significantly enhance accuracy and may increase runtime.                                                               |
# | Activation           | The activation function influences the output of each neuron in the hidden layers, affecting the network's accuracy.                                             | I used the 'relu' activation function, which typically provides good performance for many problems. This function helps convert the input to the desired output (0/1 in this case). The 'relu' function was found to produce higher accuracy percentages than other functions. |
# | Solver               | The method for updating the weights in the network. I used 'adam' for efficient training.                                                                       | 'Adam' is an adaptive learning rate optimization algorithm that's been designed for training deep neural networks. It generally performs well and converges quickly compared to other solvers.                                                                                     |
# | Learning rate        | Defines the rate at which the network's weights are updated. It can affect the network's convergence and accuracy.                                              | I used a constant learning rate. While the impact on accuracy can vary, a well-chosen learning rate can help the model converge efficiently.                                                                                                                                     |
# | Max iterations       | The maximum number of iterations for training the model.                                                                                                       | The model was trained with a maximum of 200 iterations. If the model did not converge within this limit, it might indicate that more iterations are needed to fully utilize the model's accuracy potential.                                                                         |
#
# The accuracy percentages obtained were not very high, indicating that the model may not have fully converged to an optimal solution within the given 200 iterations. More iterations might be necessary to fully harness the model's potential on the training and validation sets. Additionally, the presence of many non-informative features could negatively impact the model's accuracy, as noted in the previous sections.

# %% [markdown]
# # SVM
#
# First, I ran a default model on the dataset :
#
# then I tuned the hyperparameters for the `SGDClassifier` using GridSearchCV. The parameters and their significance are as follows:
#
# | Parameter | Meaning | Model Impact |
# |-----------|---------|--------------|
# | alpha | Regularization strength. Higher values mean stronger regularization. | Helps to prevent overfitting by penalizing large coefficients. |
# | penalty | Specifies the norm used in the penalization ('l2', 'l1', 'elasticnet'). | Different norms can lead to different model performance. |
#
# The best parameters found were: `alpha=[Best alpha]`, `penalty=[Best penalty]`. These parameters provided a good balance between bias and variance, resulting in improved model performance.

# %%
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

svm_model_initial = SVC(random_state=42, probability=True)
svm_model_initial.fit(X_train, y_train)

train_accuracy_initial = accuracy_score(y_train, svm_model_initial.predict(X_train))
validation_accuracy_initial = accuracy_score(y_test, svm_model_initial.predict(X_test))
roc_auc_train_initial = roc_auc_score(y_train, svm_model_initial.predict_proba(X_train)[:,1])
roc_auc_val_initial = roc_auc_score(y_test, svm_model_initial.predict_proba(X_test)[:,1])

print(f'Initial Train Accuracy: {train_accuracy_initial}')
print(f'Initial Validation Accuracy: {validation_accuracy_initial}')
print(f'Initial Train ROC AUC: {roc_auc_train_initial}')
print(f'Initial Validation ROC AUC: {roc_auc_val_initial}')
# Out:
# Initial Train Accuracy: 0.7882030536343468
# Initial Validation Accuracy: 0.7734864300626305
# Initial Train ROC AUC: 0.8341569161647211
# Initial Validation ROC AUC: 0.7655699258870214

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
sgd_model = SGDClassifier(loss='log', random_state=42)
param_grid = {
    'alpha': [0.0001, 0.001, 0.01, 0.1, 1],
    'penalty': ['l2', 'l1', 'elasticnet']
}

grid_search_sgd = GridSearchCV(estimator=sgd_model, param_grid=param_grid, cv=3, scoring='roc_auc', return_train_score=True, n_jobs=-1)
grid_search_sgd.fit(X_train, y_train)

best_params_sgd = grid_search_sgd.best_params_
print(f'Best Parameters: {best_params_sgd}')

best_sgd_model = grid_search_sgd.best_estimator_
best_sgd_model.fit(X_train, y_train)

train_accuracy_optimized = accuracy_score(y_train, best_sgd_model.predict(X_train))
validation_accuracy_optimized = accuracy_score(y_test, best_sgd_model.predict(X_test))
roc_auc_train_optimized = roc_auc_score(y_train, best_sgd_model.predict_proba(X_train)[:,1])
roc_auc_val_optimized = roc_auc_score(y_test, best_sgd_model.predict_proba(X_test)[:,1])

print(f'Optimized Train Accuracy: {train_accuracy_optimized}')
print(f'Optimized Validation Accuracy: {validation_accuracy_optimized}')
print(f'Optimized Train ROC AUC: {roc_auc_train_optimized}')
print(f'Optimized Validation ROC AUC: {roc_auc_val_optimized}')
# Out:
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# Best Parameters: {'alpha': 0.01, 'penalty': 'elasticnet'}
# C:\Users\mayoa\anaconda3\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# Optimized Train Accuracy: 0.7788725042411588
# Optimized Validation Accuracy: 0.7734864300626305
# Optimized Train ROC AUC: 0.7985975303085323
# Optimized Validation ROC AUC: 0.7887212958099907

# %%
y_pred_svm = best_sgd_model.predict(X_test)

cm_svm = confusion_matrix(y_test, y_pred_svm)

disp_svm = ConfusionMatrixDisplay(confusion_matrix=cm_svm, display_labels=['Not Looking for Job Change', 'Looking for Job Change'])
disp_svm.plot(cmap='Blues')
plt.title('Confusion Matrix - SVM')
plt.show()

# %% [markdown]
# ## Model Performance Analysis
#
# In this section, I am going to discuss the performances of the models used in this project: Decision Tree, Neural Network, and Support Vector Machine (SVM). We need to understand not just which model has done the best but also why some models did better than others, where they struggled, and whether the underlying data may be contributing to these issues.
#
# ### Model Comparison Overview
#
# | Metric/Model           | Decision Tree | Neural Network | SVM          |
# |------------------------|---------------|----------------|--------------|
# | Training Accuracy      | 82%           | 84%            | 78%          |
# | Validation Accuracy    | 78.5%         | 76%            | 77%          |
# | Validation ROC AUC     | 0.76          | 0.74           | 0.76         |
#
# From the above table, it's evident that the Decision Tree outperformed the Neural Network and SVM in both accuracy and AUC metrics on the validation set. However, to fully understand model performance, we need to look beyond accuracy metrics and explore confusion matrices for each model.

# %% [markdown]
# ### Confusion Matrix Analysis

# %% [markdown]
# We can do this by checking the confusion matrices, which would give us insight into each model's ability to differentiate between the classes. Let's see how each model did.
#
# Speaking of the Decision Tree model, both classes were predicted with relatively good balance. It obtained 569 true positive and 2,445 true negative predictions. However, the model managed to give 435 false positive predictions and 383 false negative ones. The results imply that, while the Decision Tree will be good at explaining general trends, at times it omits some details, mostly in capturing employees likely to shift their jobs.
#
# The overall result can be observed when moving to the Neural Network model, which contained 479 true positives and 2463 true negatives but in turn brought 417 false positives and 473 false negatives. In other words, it shows the fact that there were more false negatives in relation to the Decision Tree points, the fact that the Neural Network really had some difficulties in recognizing those intending to change jobs. This trend suggests that the model may overfit to the majority class—those who do not want to change jobs.
#
# Lastly, SVM had a different issue altogether with the model. It was able to find 297 true positives and 2,667 true negatives, but, on the other hand, turned out to have the highest false negatives at 655, paired with 213 false positives. The same can be observed from the fact that the SVM model brought serious trouble in providing an efficient prediction related to the job changes. The complexities are not captured by the linear decision boundary of the SVM in the data, therefore leading to misclassification.

# %% [markdown]
# ### Areas of Improvement and Data Challenges

# %% [markdown]
# Using these models, it seemed to predict the majority class, which means that they are better in capturing those who did not want to change their job. This problem of class imbalance made it rather difficult for most models, especially the SVM, to correctly predict those really looking for a job change.
#
# Even though the features that we have provided serve well for the inferences from the Decision Tree and Neural Network models, the results indicate that our feature selection might still be inefficient. It is probably the case that we miss important factors which otherwise affect the likelihood of changing jobs.
#
# The last thing is that the Neural Network presented overfitting, as it didn't converge inside the maximum number of iterations. This is alarming because it indicates that the model performed much better on the training data than on validation data. One of the ways we can prevent this overfitting is through regularization, more data, or changing the model's architecture such that it generalizes well.

# %% [markdown]
# ### Model Learning Insights

# %% [markdown]
# **Decision tree**:  this model is known for it's ability to handle non linear relationship variables,it was the best performer out of the three models ,however it still missed predicting instances in both classes ( could be due to overfitting or lack of features
#
# **Neural Network** this model is known for it's flexibility and ability to capture complex patterns however its noticable that it's performence was hindred by overfitting ( also the warning supports this claim) i think that maybe further tuning  or additional data will help this model to perform bettern.
#
# **SVM** this was the worst model for this specific task ,probably due to it's linear decision approach.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The Decision Tree emerged as the most effective model for this task, but with evident room for improvement. Future steps could involve enhancing feature selection based on more advanced techniques will be implied in the next section.

# %% [markdown]
# # Improving the Selected Model -Decision Tree
#
# According to the findings of the previous section, my chosen model is the Decision Tree. I will now examine how I can improve this model.
#
# | Problem                                | Explanation                                                                                      | Solution                                                                                                  | Expected Improvement                                                                                        |
# |----------------------------------------|--------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|
# | Many features with low importance      | I suspect this may create "noise" in the learning model, preventing it from realizing its full accuracy potential | Provide the model with the most important features for learning                                           | Validation accuracy of the model                                                                            |
# | Size of the validation set             | Different sizes may provide different accuracy rates for the same model                          | Perform trial and error on different validation set sizes                                                 | Validation accuracy of the model                                                                            |
#
# I conducted five improvement attempts for my model. Here are the details:
# - The improvements referring to the size of the validation set aim to improve the data.
# - The improvements referring to the varying number of features aim to improve the overall model.
# - Additionally, improvement #5 involves creating an improved model based on the existing one. Below are the outputs of the accuracy for each of the improvements:

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
test_sizes = np.arange(0.1, 0.35, 0.05)
res2 = pd.DataFrame()

for size in test_sizes:
    X_train, X_val, y_train, y_val = train_test_split(X_imputed, y, test_size=size, random_state=123)
    dt2_model = DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=123)
    dt2_model.fit(X_train, y_train)
    
    scores2 = cross_val_score(dt2_model, X_train, y_train, cv=10, scoring='roc_auc')
    res2 = pd.concat([res2, pd.DataFrame({'size': [size], 'train_acc': [accuracy_score(y_train, dt2_model.predict(X_train))], 'val_acc': [scores2.mean()]})], ignore_index=True)

print(res2)

plt.figure(figsize=(10, 5))
plt.plot(res2['size'], res2['train_acc'], label='Train Accuracy', marker='o')
plt.plot(res2['size'], res2['val_acc'], label='Validation ROC AUC', marker='o')
plt.xlabel('Test Size')
plt.ylabel('Score')
plt.title('Effect of Test Size on Model Performance')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    size  train_acc   val_acc
# 0  0.10   0.800777  0.781919
# 1  0.15   0.800970  0.785872
# 2  0.20   0.804058  0.783833
# 3  0.25   0.802339  0.781462
# 4  0.30   0.804325  0.786287

# %% [markdown]
# Based on the above graph, during the change of test size, the training accuracy of the Decision Tree model always stays at about 80%. However, the ROC AUC on validation fluctuates a little. The best performance occurred when the test size was 0.15, after which it decreased a bit as it got larger. This means that the model is very stable. However, a smaller test size slightly enhances its performance on the validation.

# %%
features_list = np.arange(1, 28, 1)
results = pd.DataFrame()

for k in features_list:
    selector = SelectKBest(chi2, k=k)
    X_train_selected = selector.fit_transform(X_train, y_train)
    X_val_selected = selector.transform(X_val)
    
    dt_model = DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=123)
    dt_model.fit(X_train_selected, y_train)
    
    val_selected = cross_val_score(dt_model, X_val_selected, y_val, cv=10, scoring='roc_auc')
    results = pd.concat([results, pd.DataFrame({'k': [k], 'train_score': [accuracy_score(y_train, dt_model.predict(X_train_selected))], 'val_score': [val_selected.mean()]})], ignore_index=True)


plt.figure(figsize=(10, 5))
plt.plot(results['k'], results['train_score'], label='Train Score', marker='o')
plt.plot(results['k'], results['val_score'], label='Validation ROC AUC', marker='o')
plt.xlabel('Number of Features (k)')
plt.ylabel('Score')
plt.title('Effect of Number of Features on Model Performance')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The graph plots the impact of number of features against the performance of the Decision Tree model: The train score and validation ROC AUC increase rapidly initially as the number of features increases but then flatten out after about 5 features, with the train score going flat at about 80% and the validation ROC AUC leveling off slightly over 75%. Beyond this point, adding more features results in very slight improvement, which possibly suggests that a few key features are good enough for optimal performance, with extra features not really adding to the model.

# %%
important_features = [
    'city_development_index', 'company_size', 'education_level', 'experience', 'training_hours',
    'last_new_job', 'relevent_experience_Has relevent experience', 'enrolled_university', 'company_type_Pvt Ltd'
]

X_important = X_imputed[important_features]

X_train_imp, X_val_imp, y_train_imp, y_val_imp = train_test_split(X_important, y, test_size=0.2, random_state=123)

improved_dt_model = DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=123)
improved_dt_model.fit(X_train_imp, y_train_imp)

train_acc_imp = improved_dt_model.score(X_train_imp, y_train_imp)
val_acc_imp = cross_val_score(improved_dt_model, X_val_imp, y_val_imp, cv=10, scoring='roc_auc').mean()

print(f'Train Accuracy: {train_acc_imp}')
print(f'Validation ROC AUC: {val_acc_imp}')
# Out:
# Train Accuracy: 0.8029492365914133
# Validation ROC AUC: 0.7302660197707913

# %%
res3 = pd.DataFrame()

for size in test_sizes:
    X_train, X_val, y_train, y_val = train_test_split(X_important, y, test_size=size, random_state=123)
    improved_dt_model.fit(X_train, y_train)
    
    scores3 = cross_val_score(improved_dt_model, X_train, y_train, cv=10, scoring='roc_auc')
    res3 = pd.concat([res3, pd.DataFrame({'size': [size], 'train_acc': [accuracy_score(y_train, improved_dt_model.predict(X_train))], 'val_acc': [scores3.mean()]})], ignore_index=True)

print(res3)

plt.figure(figsize=(10, 5))
plt.plot(res3['size'], res3['train_acc'], label='Train Accuracy', marker='o')
plt.plot(res3['size'], res3['val_acc'], label='Validation ROC AUC', marker='o')
plt.xlabel('Test Size')
plt.ylabel('Score')
plt.title('Combined Effect of Test Size and Feature Selection')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    size  train_acc   val_acc
# 0  0.10   0.801705  0.784689
# 1  0.15   0.802321  0.782582
# 2  0.20   0.802949  0.784850
# 3  0.25   0.801016  0.779052
# 4  0.30   0.803505  0.786978

# %% [markdown]
# in this graph "Combined Effect of Test Size and Feature Selection on Model Performance" we can see that the train accuracy does not vary much across test sizes, while scores stay around 0.80 to 0.82, whereas the validation ROC AUC scores are a bit different and generally sit around 0.78. That again suggests that feature selection coupled with various test sizes did not have a significant impact on the generalization capability of the model, given that its validation performances were quite consistent. However, stability of the validation ROC AUC can also suggest that bias and variance changes keep a balanced trade-off, which signifies that the combination of feature and size of test is appropriate and robust enough to maintain the performance of the model across different splits of data.

# %%
param_grid_rf = {
    'max_depth': np.arange(1, 10, 1),
    'criterion': ['entropy', 'gini'],
    'max_samples': np.arange(0.1, 1.0, 0.1)
}

rf_grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=123), param_grid=param_grid_rf, cv=10, scoring='roc_auc', return_train_score=True)
rf_grid_search.fit(X_train_imp, y_train_imp)

best_params_rf = rf_grid_search.best_params_
print(f'The best parameters combination is: {best_params_rf}')

best_rf_model = rf_grid_search.best_estimator_
best_rf_model.fit(X_train_imp, y_train_imp)

train_score_rf = best_rf_model.score(X_train_imp, y_train_imp)
val_score_rf = cross_val_score(best_rf_model, X_val_imp, y_val_imp, cv=10, scoring='roc_auc').mean()

print(f'Train Score: {train_score_rf}')
print(f'Validation ROC AUC: {val_score_rf}')
# Out:
# The best parameters combination is: {'criterion': 'entropy', 'max_depth': 9, 'max_samples': 0.5}
# Train Score: 0.8236330418895994
# Validation ROC AUC: 0.7887969142484057

# %%
y_pred_rf = best_rf_model.predict(X_val_imp)

cm_rf = confusion_matrix(y_val_imp, y_pred_rf)

disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf, display_labels=['Not Looking for Job Change', 'Looking for Job Change'])
disp_rf.plot(cmap='Blues')
plt.title('Confusion Matrix - Random Forest')
plt.show()

# %% [markdown]
# using Random forest offers a slight improvemnt from the original decision tree, both in train scor and validation score , which was predictable due to the fact that Random forest model is more robust and stable, this was the best attempt to improve the result for the original decision tree.

# %% [markdown]
# # Summary

# %% [markdown]
# ## Project Overview

# %% [markdown]
# This project dealt with the problem of designing a machine learning model for the classification of employees who are on the lookout for a change of job. Therefore, through careful preprocessing of data and exploratory data analysis, we want to develop a really good predictive model. Finally, the last chapter will conclude by summarizing the key steps, findings, and reflections that define the road from raw data to actionable insights.
#  simple Decision Tree, it has taken me on this journey through several models, tuning parameters, constant evaluation, and finally reaching the best results by using the powerful ensemble methods, Random Forests, to get 79% validation accuracy. And this project gives one more reason why the value of understanding data, selecting the correct features, and methodically tuning model parameters to develop accurate and generalizable models is so high. Therefore, the experience gained from this project will serve to inculcate into the mind those important qualities which should be held on the forefront in the field of data science: patience, precision, and persistence.

# %% [markdown]
# ## Data Understanding and Preparation

# %% [markdown]
# The first step in the project was going through understanding and preparing the dataset. Each and every variable—be it continuous, discrete, or nominal—was scrutinized for its range and meaning within the context of the classification job. This understanding has set a good base for effective feature selection and engineering, which is very important for model performance. It also helps in determining the distribution of the target variable and the importance of dealing with imbalanced classes, common in a classification task.

# %% [markdown]
# ## Model Development and Assessment

# %% [markdown]
# The process explored a number of machine learning algorithms, starting with a baseline Decision Tree model. The base model overfits in all experiments therefore, hyperparameter tuning was applied through Grid Search, which brought significant improvement in the performance of the model and increased the value of fine-tuning the parameters of this model.
#
# More testing with ANNs and SVMs revealed some deeper insights, though all the further possible combinations did not beat the base Decision Tree. An experiment involving k-medoids clustering has also been included to gain a better understanding of underlying structures within the data; it has shown that optimally, the dataset could be divided into two clusters.
#
# Ultimately, with a focus on further development of the Decision Tree model, the process implemented was a Random Forest with hyperparameter tuning. This model performed best among the others. The validation accuracy obtained by the model was around 79%, which indicates the good handling capacity of ensemble methods over complex datasets.

# %% [markdown]
# ## Key Insights

# %% [markdown]
# **Model Selection and Tuning**: the process of model selection, hyperparameter tuning, and validation was necessary to come up with a robust predictive model. The Decision Tree model properly tuned offered the best fit for the task.
#
#
# **Importance of Feature Selection**: The project showed the importance of the selection of relevant feature,good selection of features can improve the model performence and at the same time it reduces the possibility of overfitting + allows it to be more generalizable.
#
#
# **best improving Methods (ensamble)**: The Random Forest model proved to be better than all by simply aggregating the results of several decision trees. The more significant performance of this model indicates the importance of ensemble methods in machine learning.

# %% [markdown]
# ## Final Reflections

# %% [markdown]
# This project shows how iterative the development of a machine learning model is: from a very simple Decision Tree, it has taken me on this journey through several models, tuning parameters, constant evaluation, and finally reaching the best results by using the powerful ensemble methods, Random Forests, to get 79% validation accuracy. And this project gives one more reason why the value of understanding data, selecting the correct features, and methodically tuning model parameters to develop accurate and generalizable models is so high. Therefore, the experience gained from this project will serve to inculcate into the mind those important qualities which should be held on the forefront in the field of data science: patience, precision, and persistence.
